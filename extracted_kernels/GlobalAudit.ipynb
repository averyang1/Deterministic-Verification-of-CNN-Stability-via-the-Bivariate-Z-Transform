# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_global_audit(csvFile):
    df = pd.read_csv(csvFile)
    kernels = df.values.reshape(-1, 3, 3)
    
    # Calculate Stability Margin (Sigma) for ALL kernels
    sigmas = [np.min(np.abs(np.fft.fft2(k, s=(32, 32)))) for k in kernels]
    
    plt.figure(figsize=(10, 6))
    plt.hist(sigmas, bins=50, color='darkslateblue', edgecolor='white', alpha=0.8)
    plt.axvline(np.mean(sigmas), color='red', linestyle='dashed', label=f'Mean Sigma: {np.mean(sigmas):.4f}')
    
    plt.title("Deterministic Audit: Stability Margin Distribution (ResNet-18 Layer 1)")
    plt.xlabel("Stability Margin ($\sigma$)")
    plt.ylabel("Kernel Count")
    plt.legend()

    plt.savefig("global_audit_histogram.png")
    print(f"Saved to: global_audit_histogram.png")  # confirms where it landed
    
   
    plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_23395/2916841107.py:13: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel("Stability Margin ($\sigma$)")

# %%
if __name__ == "__main__":
    # Make sure this filename matches your actual CSV filename
    plot_global_audit("resnet18_layer1_3x3.csv")
# Out:
# Saved to: global_audit_histogram.png
